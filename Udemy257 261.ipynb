# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data=pd.read_csv('Countries-exercise.csv')
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
data_position=data.iloc[:,1:3]

# %%
plt.scatter(data['Longitude'],data['Latitude'])

# %%
kmeans=KMeans(3)

# %%
kmeans.fit(data_position)
# Out:
# KMeans(n_clusters=3)

# %%
cluster_identify=kmeans.predict(data_position)

# %%
data_with_cluster=data.copy()
data_with_cluster['cluster']=cluster_identify

# %%
plt.scatter(data_with_cluster['Longitude'],data_with_cluster['Latitude'],c=cluster_identify,cmap='rainbow')
plt.savefig('KMeans7')

# %%
wcss=[]

for i in range(1,11):
    kmeans=KMeans(i)
    kmeans.fit(data_position)
    wcss_iter=kmeans.inertia_
    wcss.append(wcss_iter)
# Out:
# C:\Users\fujir\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
wcss_number=range(1,11)
plt.plot(wcss_number,wcss)
